# %%
a = 12
a = str(a)
print(type(a))
a = float(a)
print(type(a))
a = bool(a)
print(type(a))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
name = "Anu"
age = "20"
print(f"My name is {name} and my age is {age}")
# Out:
# My name is Anu and my age is 20
